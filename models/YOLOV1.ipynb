# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import os
import cv2
import imghdr
from ultralytics import YOLO
import pandas as pd
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import torch 
if torch.cuda.is_available(): 
    print("CUDA is available. Using GPU.") 
else: 
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is available. Using GPU.

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA version: {torch.version.cuda}")
print(f"Is CUDA available: {torch.cuda.is_available()}")
print(f"Number of GPUs: {torch.cuda.device_count()}")
print(f"CUDA device name: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'N/A'}")
print(f"CUDA current device: {torch.cuda.current_device() if torch.cuda.is_available() else 'N/A'}")
# Out:
# PyTorch version: 2.5.1+cu124
# CUDA version: 12.4
# Is CUDA available: True
# Number of GPUs: 1
# CUDA device name: NVIDIA GeForce RTX 3070 Laptop GPU
# CUDA current device: 0

# %%
torch.cuda.empty_cache()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 torch.cuda.empty_cache()
#
# File ~\Projects\RecyclerPro\venv\Lib\site-packages\torch\cuda\memory.py:192, in empty_cache()
#     181 r"""Release all unoccupied cached memory currently held by the caching
#     182 allocator so that those can be used in other GPU application and visible in
#     183 `nvidia-smi`.
#    (...)
#     189     more details about GPU memory management.
#     190 """
#     191 if is_initialized():
# --> 192     torch._C._cuda_emptyCache()
#
# RuntimeError: CUDA error: out of memory
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import os
from ultralytics import YOLO
model = YOLO("yolo11n.pt")
results = model.train(data="data.yaml", epochs=600, imgsz=1280, batch=-1, device=0, patience=100, cache='disk')
# Out:
# New https://pypi.org/project/ultralytics/8.3.75 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model = YOLO("yolo11n.pt")

# %%
# !nvidia-smi
# Out:
# Fri Dec 13 22:49:08 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.61                 Driver Version: 551.61         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   41C    P8             17W /  115W |    7115MiB /   8192MiB |     35%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# YOLO11n summary (fused): 238 layers, 2,585,662 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning C:\Users\rlaks\Projects\datasets\valid\labels.cache... 1704 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1704/1704 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 107/107 [00:42<00:00,  2.49it/s]
#                    all       1704       4830      0.362      0.268      0.219      0.154
#         Aluminium foil         48         62      0.418       0.29      0.295      0.234
#             Bottle cap        347        459       0.36      0.577      0.458      0.323
#                 Bottle        275        320      0.507      0.449      0.419      0.273
#           Broken glass         13        123          1          0          0          0
# ...

# %%
# model.export(format='tf_js')
from ultralytics import YOLO

model = YOLO("C:/Users/rlaks/Projects/RecyclerPro/runs/detect/train21/weights/best.pt", task="detect")
results = model(source="C:/Users/rlaks/Projects/RecyclerPro/backend/test/images/000021_jpg.rf.519189f9f9267eb248fd9c7fc26ae868.jpg")

for result in results:
    print(result.boxes.data)
    result.show()  # uncomment to view each result image
# Out:
# image 1/1 C:\Users\rlaks\Projects\RecyclerPro\backend\test\images\000021_jpg.rf.519189f9f9267eb248fd9c7fc26ae868.jpg: 1280x1280 1 Bottle cap, 1 Can, 1 Carton, 14.3ms
# Speed: 12.4ms preprocess, 14.3ms inference, 2.0ms postprocess per image at shape (1, 3, 1280, 1280)
# tensor([[306.3741, 196.2646, 331.9141, 273.8487,   0.9109,   1.0000],
#         [146.7528, 218.7083, 192.5184, 260.5374,   0.9081,   5.0000],
#         [199.5145, 161.4131, 224.0805, 209.7195,   0.8946,   4.0000]], device='cuda:0')

# %%
from ultralytics import YOLO
import os

# Load a model
model = YOLO("../../RecyclerPro/runs/detect/train31/weights/best.pt")  # load a partially trained model

# Resume training
results = model.train(resume = True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.75 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3070 Laptop GPU, 8192MiB)
# ...

# %%
model.export()
# Out:
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO11n summary (fused): 238 layers, 2,585,662 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'C:\Users\rlaks\Projects\RecyclerPro\runs\detect\train22\weights\best.pt' with input shape (1, 3, 1280, 1280) BCHW and output shape(s) (1, 22, 33600) (5.4 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success  2.9s, saved as 'C:\Users\rlaks\Projects\RecyclerPro\runs\detect\train22\weights\best.torchscript' (10.7 MB)
#
# Export complete (3.6s)
# Results saved to C:\Users\rlaks\Projects\RecyclerPro\runs\detect\train22\weights
# Predict:         yolo predict task=detect model=C:\Users\rlaks\Projects\RecyclerPro\runs\detect\train22\weights\best.torchscript imgsz=1280
# Validate:        yolo val task=detect model=C:\Users\rlaks\Projects\RecyclerPro\runs\detect\train22\weights\best.torchscript imgsz=1280 data=data.yaml
# ...

# %%
from ultralytics.utils.benchmarks import benchmark
from ultralytics import YOLO

model = YOLO("../runs/detect/train22/weights/best.pt", task="detect")

benchmark(model=model, data="data.yaml", imgsz=640, half=False, device=0)
# Out:
# Setup complete  (16 CPUs, 31.9 GB RAM, 700.2/952.6 GB disk)
#
# Benchmarks complete for best.pt on data.yaml at imgsz=640 (1535.87s)
#                    Format Status  Size (MB)  metrics/mAP50-95(B)  Inference time (ms/im)    FPS
# 0                 PyTorch               5.4               0.2209                   14.37  69.58
# 1             TorchScript              10.4               0.2065                   10.10  99.03
# 2                    ONNX              10.1               0.2065                   36.33  27.53
# 3                OpenVINO               0.0                  NaN                     NaN    NaN
# 4                TensorRT               0.0                  NaN                     NaN    NaN
# 5                  CoreML               0.0                  NaN                     NaN    NaN
# 6   TensorFlow SavedModel              26.2               0.2065                   40.99  24.39
# ...

# %%
import onnx
from onnx2tf import convert

# Load the ONNX model
onnx_model_path = '../runs/detect/train22/weights/best.onnx'
onnx_model = onnx.load(onnx_model_path)

# Convert the ONNX model to TensorFlow.js format
convert(
    input_onnx_file_path=onnx_model_path,
    output_folder_path='models/tfjs_model',
)
# Out:
# Model optimizing started ============================================================
# Traceback (most recent call last):
#   File "C:\Users\rlaks\Projects\RecyclerPro\venv\Lib\site-packages\onnx2tf\onnx2tf.py", line 645, in convert
#     result = subprocess.check_output(
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rlaks\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 466, in check_output
#     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rlaks\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\rlaks\AppData\Local\Programs\Python\Python311\Lib\subprocess.py", line 1024, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
inference_so_directory = 'C:\\Users\\rlaks\\Python\\Python311\\Lib\\site-packages\\tensorflow_decision_forests\\tensorflow\\ops\\inference'
os.environ['PATH'] += os.pathsep + inference_so_directory

model = YOLO("../runs/detect/train22/weights/best.pt")
model.export(format="tfjs")
# Out:
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO11n summary (fused): 238 layers, 2,585,662 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from '..\runs\detect\train22\weights\best.pt' with input shape (1, 3, 1280, 1280) BCHW and output shape(s) (1, 22, 33600) (5.4 MB)
# requirements: Ultralytics requirement ['onnx2tf>1.17.5,<=1.22.3'] not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#
# requirements: AutoUpdate success  8.3s, installed 1 package: ['onnx2tf>1.17.5,<=1.22.3']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.15.1...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.45...
# ONNX: export success  1.5s, saved as '..\runs\detect\train22\weights\best.onnx' (10.6 MB)
# ...

# %%
from ultralytics import YOLO

# Load a YOLOv8n PyTorch model
model = YOLO("best.pt")

# Export the model to NCNN format
model.export(format="ncnn", imgsz=640)
# Out:
# Ultralytics 8.3.27  Python-3.11.1 torch-2.5.1+cu124 CPU (AMD Ryzen 7 5800H with Radeon Graphics)
# YOLO11n summary (fused): 238 layers, 2,585,662 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 22, 8400) (5.4 MB)
#
# TorchScript: starting export with torch 2.5.1+cu124...
# TorchScript: export success  3.0s, saved as 'best.torchscript' (10.4 MB)
# requirements: Ultralytics requirement ['ncnn'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 4.0/4.0 MB 29.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success  3.3s, installed 1 package: ['ncnn']
# requirements:  Restart runtime or rerun command for updates to take effect
#
#
# NCNN: starting export with NCNN 1.0.20241226...
# NCNN: WARNING  PNNX not found. Attempting to download binary file from https://github.com/pnnx/pnnx/.
# ...
